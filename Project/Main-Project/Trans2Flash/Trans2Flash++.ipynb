# %% [markdown]
# #Trans2Flash

# %% [markdown]
# ##Shortcut

# %%
# !pip install textblob
# !pip install --upgrade googletrans==4.0.0-rc1
from textblob import TextBlob
from googletrans import Translator

def is_valid_english_word(word):
    valid_chars = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ")
    is_valid = len(word) > 2 and all(char in valid_chars for char in word) and len(word) < 20
    return is_valid

def is_invalid_thai_word(word):
    invalid_chars = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")
    is_invalid = any(char in invalid_chars for char in word)
    return is_invalid

def count_sentences(file_path):
    sentence_count = 0
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            sentence_count += 1
    return sentence_count

def load_vocab_to_set(filename):
    vocab_set = set()
    with open(filename, 'r') as file:
        for line in file:
            vocab_set.add("".join(line.strip().split(',')[0]))
    return vocab_set

translator = Translator()
vocab = []
set_list_of_vocab = load_vocab_to_set('list_of_vocab.txt')
file_path = 'from_translate.txt'
sentence_count = count_sentences(file_path) / 3 - 2 + 1
n = 0

with open(file_path, 'r', encoding='utf-8') as file:
    for _ in range(6):
        file.readline()
    for line in file:
        n += 1
        print(f"{100*n/sentence_count:.2f}% complete")
        try:
            language1, useless, language2 = line.split()
        except ValueError:
            print(f"Issue found on line {line}: {line.strip()}")
        word1 = file.readline().strip()
        word2 = file.readline().strip()
        if language1 == "อังกฤษ" and language2 == "ไทย" and is_valid_english_word(word1):
            try:
                if word1.lower() in set_list_of_vocab:
                    continue
                blob = TextBlob(word1)
                corrected_word1 = str(blob.correct())
                if not corrected_word1 == word1:
                    continue
                translated_word1 = translator.translate(corrected_word1, dest='th').text
                if translated_word1.lower() == corrected_word1.lower() or is_invalid_thai_word(translated_word1) or corrected_word1.count(" ") > 2:
                    continue
                if translated_word1 is not None:
                    vocab.append((word1.lower(), translated_word1))
            except Exception as e:
               print(f"Translation failed for '{corrected_word1}': {e}")
        elif language1 == "ไทย" and language2 == "อังกฤษ" and is_valid_english_word(word2):
            try:
                if word2.lower() in set_list_of_vocab:
                    continue
                blob = TextBlob(word2)
                corrected_word2 = str(blob.correct())
                if not corrected_word2 == word2:
                    continue
                translated_word2 = translator.translate(corrected_word2, dest='th').text
                if translated_word2.lower() == corrected_word2.lower() or is_invalid_thai_word(translated_word2) or corrected_word2.count(" ") > 2:
                    continue
                if translated_word2 is not None:
                    vocab.append((word2.lower(), translated_word2))
            except Exception as e:
               print(f"Translation failed for '{corrected_word2}': {e}")

vocab_sorted = sorted(set(vocab))
output_file_path = 'vocab.txt'

print(vocab_sorted)

with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for pair in vocab_sorted:
        output_file.write(f"{pair[0]},{pair[1]}\n")

print(f"Vocabulary written to {output_file_path}")
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.12.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.4 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.7 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.6 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.1 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.5 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.12.1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.2 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.5 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=668b8db05415f1133bb53b896df2a2c7dbfb71d4526bf0f6bc0fff1752680ed0
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.2.2 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.54.5 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# 0.27% complete
# 0.54% complete
# 0.81% complete
# 1.08% complete
# 1.35% complete
# 1.62% complete
# 1.89% complete
# 2.15% complete
# 2.42% complete
# 2.69% complete
# 2.96% complete
# 3.23% complete
# 3.50% complete
# 3.77% complete
# 4.04% complete
# 4.31% complete
# 4.58% complete
# 4.85% complete
# 5.12% complete
# 5.39% complete
# 5.66% complete
# 5.92% complete
# 6.19% complete
# 6.46% complete
# 6.73% complete
# 7.00% complete
# 7.27% complete
# 7.54% complete
# 7.81% complete
# 8.08% complete
# 8.35% complete
# 8.62% complete
# 8.89% complete
# 9.16% complete
# 9.43% complete
# 9.69% complete
# 9.96% complete
# 10.23% complete
# 10.50% complete
# 10.77% complete
# 11.04% complete
# 11.31% complete
# 11.58% complete
# 11.85% complete
# 12.12% complete
# 12.39% complete
# 12.66% complete
# 12.93% complete
# 13.20% complete
# 13.46% complete
# 13.73% complete
# 14.00% complete
# 14.27% complete
# 14.54% complete
# 14.81% complete
# 15.08% complete
# 15.35% complete
# 15.62% complete
# 15.89% complete
# 16.16% complete
# 16.43% complete
# 16.70% complete
# 16.97% complete
# 17.24% complete
# 17.50% complete
# 17.77% complete
# 18.04% complete
# 18.31% complete
# 18.58% complete
# 18.85% complete
# 19.12% complete
# 19.39% complete
# 19.66% complete
# 19.93% complete
# 20.20% complete
# 20.47% complete
# 20.74% complete
# 21.01% complete
# 21.27% complete
# 21.54% complete
# 21.81% complete
# 22.08% complete
# 22.35% complete
# 22.62% complete
# 22.89% complete
# 23.16% complete
# 23.43% complete
# 23.70% complete
# 23.97% complete
# 24.24% complete
# 24.51% complete
# 24.78% complete
# 25.04% complete
# 25.31% complete
# 25.58% complete
# 25.85% complete
# 26.12% complete
# 26.39% complete
# 26.66% complete
# 26.93% complete
# 27.20% complete
# 27.47% complete
# 27.74% complete
# 28.01% complete
# 28.28% complete
# 28.55% complete
# 28.82% complete
# 29.08% complete
# 29.35% complete
# 29.62% complete
# 29.89% complete
# 30.16% complete
# 30.43% complete
# 30.70% complete
# 30.97% complete
# 31.24% complete
# 31.51% complete
# 31.78% complete
# 32.05% complete
# 32.32% complete
# 32.59% complete
# 32.85% complete
# 33.12% complete
# 33.39% complete
# 33.66% complete
# 33.93% complete
# 34.20% complete
# 34.47% complete
# 34.74% complete
# 35.01% complete
# 35.28% complete
# 35.55% complete
# 35.82% complete
# 36.09% complete
# 36.36% complete
# 36.62% complete
# 36.89% complete
# 37.16% complete
# 37.43% complete
# 37.70% complete
# 37.97% complete
# 38.24% complete
# 38.51% complete
# 38.78% complete
# 39.05% complete
# 39.32% complete
# 39.59% complete
# 39.86% complete
# 40.13% complete
# 40.39% complete
# 40.66% complete
# 40.93% complete
# 41.20% complete
# 41.47% complete
# 41.74% complete
# 42.01% complete
# 42.28% complete
# 42.55% complete
# 42.82% complete
# 43.09% complete
# 43.36% complete
# 43.63% complete
# 43.90% complete
# 44.17% complete
# 44.43% complete
# 44.70% complete
# 44.97% complete
# 45.24% complete
# 45.51% complete
# 45.78% complete
# 46.05% complete
# 46.32% complete
# 46.59% complete
# 46.86% complete
# 47.13% complete
# 47.40% complete
# 47.67% complete
# 47.94% complete
# 48.20% complete
# 48.47% complete
# 48.74% complete
# 49.01% complete
# 49.28% complete
# 49.55% complete
# 49.82% complete
# 50.09% complete
# 50.36% complete
# 50.63% complete
# 50.90% complete
# 51.17% complete
# 51.44% complete
# 51.71% complete
# 51.97% complete
# 52.24% complete
# 52.51% complete
# 52.78% complete
# 53.05% complete
# 53.32% complete
# 53.59% complete
# 53.86% complete
# 54.13% complete
# 54.40% complete
# 54.67% complete
# 54.94% complete
# 55.21% complete
# 55.48% complete
# 55.75% complete
# 56.01% complete
# 56.28% complete
# 56.55% complete
# 56.82% complete
# 57.09% complete
# 57.36% complete
# 57.63% complete
# 57.90% complete
# 58.17% complete
# 58.44% complete
# 58.71% complete
# 58.98% complete
# 59.25% complete
# 59.52% complete
# 59.78% complete
# 60.05% complete
# 60.32% complete
# 60.59% complete
# 60.86% complete
# 61.13% complete
# 61.40% complete
# 61.67% complete
# 61.94% complete
# 62.21% complete
# 62.48% complete
# 62.75% complete
# 63.02% complete
# 63.29% complete
# 63.55% complete
# 63.82% complete
# 64.09% complete
# 64.36% complete
# 64.63% complete
# 64.90% complete
# 65.17% complete
# 65.44% complete
# 65.71% complete
# 65.98% complete
# 66.25% complete
# 66.52% complete
# 66.79% complete
# 67.06% complete
# 67.32% complete
# 67.59% complete
# 67.86% complete
# 68.13% complete
# 68.40% complete
# 68.67% complete
# 68.94% complete
# 69.21% complete
# 69.48% complete
# 69.75% complete
# 70.02% complete
# 70.29% complete
# 70.56% complete
# 70.83% complete
# 71.10% complete
# 71.36% complete
# 71.63% complete
# 71.90% complete
# 72.17% complete
# 72.44% complete
# 72.71% complete
# 72.98% complete
# 73.25% complete
# 73.52% complete
# 73.79% complete
# 74.06% complete
# 74.33% complete
# 74.60% complete
# 74.87% complete
# 75.13% complete
# 75.40% complete
# 75.67% complete
# 75.94% complete
# 76.21% complete
# 76.48% complete
# 76.75% complete
# 77.02% complete
# 77.29% complete
# 77.56% complete
# 77.83% complete
# 78.10% complete
# 78.37% complete
# 78.64% complete
# 78.90% complete
# 79.17% complete
# 79.44% complete
# 79.71% complete
# 79.98% complete
# 80.25% complete
# 80.52% complete
# 80.79% complete
# 81.06% complete
# 81.33% complete
# 81.60% complete
# 81.87% complete
# 82.14% complete
# 82.41% complete
# 82.68% complete
# 82.94% complete
# 83.21% complete
# 83.48% complete
# 83.75% complete
# 84.02% complete
# 84.29% complete
# 84.56% complete
# 84.83% complete
# 85.10% complete
# 85.37% complete
# 85.64% complete
# 85.91% complete
# 86.18% complete
# 86.45% complete
# 86.71% complete
# 86.98% complete
# 87.25% complete
# 87.52% complete
# 87.79% complete
# 88.06% complete
# 88.33% complete
# 88.60% complete
# 88.87% complete
# 89.14% complete
# 89.41% complete
# 89.68% complete
# 89.95% complete
# 90.22% complete
# 90.48% complete
# 90.75% complete
# 91.02% complete
# 91.29% complete
# 91.56% complete
# 91.83% complete
# 92.10% complete
# 92.37% complete
# 92.64% complete
# 92.91% complete
# 93.18% complete
# 93.45% complete
# 93.72% complete
# 93.99% complete
# 94.25% complete
# 94.52% complete
# 94.79% complete
# 95.06% complete
# 95.33% complete
# 95.60% complete
# 95.87% complete
# 96.14% complete
# 96.41% complete
# 96.68% complete
# 96.95% complete
# 97.22% complete
# 97.49% complete
# 97.76% complete
# 98.03% complete
# 98.29% complete
# 98.56% complete
# 98.83% complete
# 99.10% complete
# 99.37% complete
# 99.64% complete
# 99.91% complete
# Issue found on line จัดการกิจกรรมทั้งหมด: จัดการกิจกรรมทั้งหมด
# [('address', 'ที่อยู่'), ('against', 'ขัดต่อ'), ('alignemnt', 'การจัดตำแหน่ง'), ('allocate', 'จัดสรร'), ('appeal', 'อุทธรณ์'), ('applicant', 'ผู้สมัคร'), ('application form', 'แบบฟอร์มใบสมัคร'), ('approach', 'เข้าใกล้'), ('arrogance', 'ความเย่อหยิ่ง'), ('as of', 'อย่าง'), ('as to', 'ว่า'), ('asset', 'สินทรัพย์'), ('atonement', 'การชดใช้'), ('benefit', 'ผลประโยชน์'), ('brace', 'รั้ง'), ('bulletin', 'แถลงการณ์'), ('capital', 'เมืองหลวง'), ('claim', 'เรียกร้อง'), ('clearance', 'การกวาดล้าง'), ('commensurate', 'มีค่าพอสมควร'), ('competitive', 'การแข่งขัน'), ('complimentary', 'อภินันทนาการ'), ('confident', 'มั่นใจ'), ('confirm', 'ยืนยัน'), ('confirm rights', 'ยืนยันสิทธิ์'), ('conflict', 'ขัดแย้ง'), ('congruity', 'ความสมานฉันท์'), ('conservation', 'การอนุรักษ์'), ('crow', 'อีกา'), ('cultivate', 'ฝึกฝน'), ('decisive', 'เด็ดขาด'), ('delegate', 'ผู้แทน'), ('deliberation', 'การไตร่ตรอง'), ('demand', 'ความต้องการ'), ('department', 'แผนก'), ('dial', 'หน้าปัด'), ('dignity', 'ศักดิ์ศรี'), ('diligent', 'ขยัน'), ('diploma', 'ประกาศนียบัตร'), ('dispose of', 'กำจัด'), ('dispute', 'ข้อพิพาท'), ('divert', 'เบี่ยงเบนความสนใจ'), ('domestic', 'ภายในประเทศ'), ('draft', 'ร่าง'), ('elevate', 'ยกระดับ'), ('eligible', 'มีสิทธิ์'), ('ensure', 'ทำให้มั่นใจ'), ('envelope', 'ซองจดหมาย'), ('escort', 'คุ้มกัน'), ('evade', 'หลีกเลี่ยง'), ('facsimile', 'โทรสาร'), ('fare', 'ค่าอาหาร'), ('fee', 'ค่าธรรมเนียม'), ('fine', 'ดี'), ('grave', 'หลุมฝังศพ'), ('idiot', 'งี่เง่า'), ('imitate', 'เลียนแบบ'), ('implement', 'ดำเนินการ'), ('imprison', 'ถูกกักขัง'), ('independent', 'เป็นอิสระ'), ('individual', 'รายบุคคล'), ('insurance', 'ประกันภัย'), ('intended', 'ตั้งใจ'), ('interference', 'การรบกวน'), ('intervene', 'แทรกแซง'), ('inversion', 'การผกผัน'), ('irrational', 'ไม่มีเหตุผล'), ('irrationally', 'อย่างไร้เหตุผล'), ('issue', 'ปัญหา'), ('liberation', 'การปลดปล่อย'), ('liberty', 'เสรีภาพ'), ('literal', 'ตามตัวอักษร'), ('lying', 'โกหก'), ('management', 'การจัดการ'), ('manifest', 'ประจักษ์'), ('market', 'ตลาด'), ('mass', 'มวล'), ('merciful', 'มีเมตตา'), ('merit', 'บุญ'), ('moderation', 'การกลั่นกรอง'), ('neglect', 'ละเลย'), ('nonetheless', 'อย่างไรก็ตาม'), ('painting', 'จิตรกรรม'), ('perceive', 'รับรู้'), ('perish', 'ล่มจม'), ('pledge', 'จำนำ'), ('popularity', 'ความนิยม'), ('population', 'ประชากร'), ('possess', 'มี'), ('post office', 'ที่ทำการไปรษณีย์'), ('practically', 'อย่างปฏิบัติ'), ('precautions', 'ข้อควรระวัง'), ('predicament', 'สถานการณ์'), ('prevent', 'ป้องกัน'), ('primary', 'หลัก'), ('pro', 'มืออาชีพ'), ('proceeds', 'รายได้'), ('promise', 'สัญญา'), ('proprietor', 'เจ้าของ'), ('provide', 'จัดเตรียม'), ('rapidly', 'อย่างรวดเร็ว'), ('receive', 'รับ'), ('refer to', 'อ้างถึง'), ('reincarnation', 'การกลับชาติมาเกิด'), ('repair', 'ซ่อมแซม'), ('repel', 'ขับไล่'), ('residue', 'สารตกค้าง'), ('resolution', 'ปณิธาน'), ('restrain', 'ยับยั้ง'), ('revenue', 'รายได้'), ('roast', 'ย่าง'), ('scholastic', 'เกี่ยวกับนักวิชาการ'), ('screw', 'สกรู'), ('sense', 'ความรู้สึก'), ('serve', 'ให้บริการ'), ('severe', 'รุนแรง'), ('sire', 'เป็นฝักบัว'), ('so as', 'ดังนั้น'), ('spread', 'การแพร่กระจาย'), ('stab', 'แทง'), ('stroke', 'จังหวะ'), ('succession', 'การสืบทอด'), ('supervise', 'ดูแล'), ('suspect', 'สงสัย'), ('suspicious', 'สงสัย'), ('towel', 'ผ้าขนหนู'), ('usage', 'การใช้งาน'), ('utmost', 'สุดซึ้ง'), ('vaporize', 'ทำให้เป็นไอ'), ('venture', 'กิจการร่วมค้า'), ('versatile', 'อเนกประสงค์'), ('whirlpool', 'วังวน'), ('yield', 'ผลผลิต')]
# Vocabulary written to vocab.txt

# %% [markdown]
# ##Import libraries

# %%
# !pip install textblob
# !pip install --upgrade googletrans==4.0.0-rc1
from textblob import TextBlob
from googletrans import Translator
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.11.1-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl.metadata (32 kB)
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl.metadata (7.2 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl.metadata (7.0 kB)
# Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 4.9 MB/s eta 0:00:00
# Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 9.9 MB/s eta 0:00:00
# Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.9 MB/s eta 0:00:00
# Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.2 MB/s eta 0:00:00
# Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.0 MB/s eta 0:00:00
# Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Downloading hstspreload-2024.11.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.8 MB/s eta 0:00:00
# Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.5 MB/s eta 0:00:00
# Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=79515c06c5118c98cfeb42a4e46033a34dfa24e1156036bc931c2d3ced91a7e8
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
#     Uninstalling h11-0.14.0:
#       Successfully uninstalled h11-0.14.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.7
#     Uninstalling httpcore-1.0.7:
#       Successfully uninstalled httpcore-1.0.7
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.2
#     Uninstalling httpx-0.27.2:
#       Successfully uninstalled httpx-0.27.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langsmith 0.1.143 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# openai 1.54.4 requires httpx<1,>=0.23.0, but you have httpx 0.13.3 which is incompatible.
# Successfully installed chardet-3.0.4 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.11.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %% [markdown]
# ##Main Code

# %%
def is_valid_english_word(word):
    valid_chars = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ ")
    is_valid = len(word) > 2 and all(char in valid_chars for char in word) and len(word) < 20
    return is_valid

def is_invalid_thai_word(word):
    invalid_chars = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ")
    is_invalid = any(char in invalid_chars for char in word)
    return is_invalid

def count_sentences(file_path):
    sentence_count = 0
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            sentence_count += 1
    return sentence_count

def load_vocab_to_set(filename):
    vocab_set = set()
    with open(filename, 'r') as file:
        for line in file:
            vocab_set.add("".join(line.strip().split(',')[0]))
    return vocab_set

translator = Translator()
vocab = []
set_list_of_vocab = load_vocab_to_set('list_of_vocab.txt')
file_path = 'from_translate.txt'
sentence_count = count_sentences(file_path) / 3 - 2 + 1
n = 0

with open(file_path, 'r', encoding='utf-8') as file:
    for _ in range(6):
        file.readline()
    for line in file:
        n += 1
        print(f"{100*n/sentence_count:.2f}% complete")
        try:
            language1, useless, language2 = line.split()
        except ValueError:
            print(f"Issue found on line {line}: {line.strip()}")
        word1 = file.readline().strip()
        word2 = file.readline().strip()
        if language1 == "อังกฤษ" and language2 == "ไทย" and is_valid_english_word(word1):
            try:
                if word1 in set_list_of_vocab:
                    continue
                blob = TextBlob(word1)
                corrected_word1 = str(blob.correct())
                if not corrected_word1 == word1:
                    continue
                translated_word1 = translator.translate(corrected_word1, dest='th').text
                if translated_word1.lower() == corrected_word1.lower() or is_invalid_thai_word(translated_word1) or corrected_word1.count(" ") > 2:
                    continue
                if translated_word1 is not None:
                    vocab.append((word1.lower(), translated_word1))
            except Exception as e:
               print(f"Translation failed for '{corrected_word1}': {e}")
        elif language1 == "ไทย" and language2 == "อังกฤษ" and is_valid_english_word(word2):
            try:
                if word2 in set_list_of_vocab:
                    continue
                blob = TextBlob(word2)
                corrected_word2 = str(blob.correct())
                if not corrected_word2 == word2:
                    continue
                translated_word2 = translator.translate(corrected_word2, dest='th').text
                if translated_word2.lower() == corrected_word2.lower() or is_invalid_thai_word(translated_word2) or corrected_word2.count(" ") > 2:
                    continue
                if translated_word2 is not None:
                    vocab.append((word2.lower(), translated_word2))
            except Exception as e:
               print(f"Translation failed for '{corrected_word2}': {e}")

vocab_sorted = sorted(set(vocab))
output_file_path = 'vocab.txt'

print(vocab_sorted)

with open(output_file_path, 'w', encoding='utf-8') as output_file:
    for pair in vocab_sorted:
        output_file.write(f"{pair[0]},{pair[1]}\n")

print(f"Vocabulary written to {output_file_path}")
# Out:
# 0.27% complete
# 0.54% complete
# 0.81% complete
# 1.08% complete
# 1.35% complete
# 1.62% complete
# 1.89% complete
# 2.15% complete
# 2.42% complete
# 2.69% complete
# 2.96% complete
# 3.23% complete
# 3.50% complete
# 3.77% complete
# 4.04% complete
# 4.31% complete
# 4.58% complete
# 4.85% complete
# 5.12% complete
# 5.39% complete
# 5.66% complete
# 5.92% complete
# 6.19% complete
# 6.46% complete
# 6.73% complete
# 7.00% complete
# 7.27% complete
# 7.54% complete
# 7.81% complete
# 8.08% complete
# 8.35% complete
# 8.62% complete
# 8.89% complete
# 9.16% complete
# 9.43% complete
# 9.69% complete
# 9.96% complete
# 10.23% complete
# 10.50% complete
# 10.77% complete
# 11.04% complete
# 11.31% complete
# 11.58% complete
# 11.85% complete
# 12.12% complete
# 12.39% complete
# 12.66% complete
# 12.93% complete
# 13.20% complete
# 13.46% complete
# 13.73% complete
# 14.00% complete
# 14.27% complete
# 14.54% complete
# 14.81% complete
# 15.08% complete
# 15.35% complete
# 15.62% complete
# 15.89% complete
# 16.16% complete
# 16.43% complete
# 16.70% complete
# 16.97% complete
# 17.24% complete
# 17.50% complete
# 17.77% complete
# 18.04% complete
# 18.31% complete
# 18.58% complete
# 18.85% complete
# 19.12% complete
# 19.39% complete
# 19.66% complete
# 19.93% complete
# 20.20% complete
# 20.47% complete
# 20.74% complete
# 21.01% complete
# 21.27% complete
# 21.54% complete
# 21.81% complete
# 22.08% complete
# 22.35% complete
# 22.62% complete
# 22.89% complete
# 23.16% complete
# 23.43% complete
# 23.70% complete
# 23.97% complete
# 24.24% complete
# 24.51% complete
# 24.78% complete
# 25.04% complete
# 25.31% complete
# 25.58% complete
# 25.85% complete
# 26.12% complete
# 26.39% complete
# 26.66% complete
# 26.93% complete
# 27.20% complete
# 27.47% complete
# 27.74% complete
# 28.01% complete
# 28.28% complete
# 28.55% complete
# 28.82% complete
# 29.08% complete
# 29.35% complete
# 29.62% complete
# 29.89% complete
# 30.16% complete
# 30.43% complete
# 30.70% complete
# 30.97% complete
# 31.24% complete
# 31.51% complete
# 31.78% complete
# 32.05% complete
# 32.32% complete
# 32.59% complete
# 32.85% complete
# 33.12% complete
# 33.39% complete
# 33.66% complete
# 33.93% complete
# 34.20% complete
# 34.47% complete
# 34.74% complete
# 35.01% complete
# 35.28% complete
# 35.55% complete
# 35.82% complete
# 36.09% complete
# 36.36% complete
# 36.62% complete
# 36.89% complete
# 37.16% complete
# 37.43% complete
# 37.70% complete
# 37.97% complete
# 38.24% complete
# 38.51% complete
# 38.78% complete
# 39.05% complete
# 39.32% complete
# 39.59% complete
# 39.86% complete
# 40.13% complete
# 40.39% complete
# 40.66% complete
# 40.93% complete
# 41.20% complete
# 41.47% complete
# 41.74% complete
# 42.01% complete
# 42.28% complete
# 42.55% complete
# 42.82% complete
# 43.09% complete
# 43.36% complete
# 43.63% complete
# 43.90% complete
# 44.17% complete
# 44.43% complete
# 44.70% complete
# 44.97% complete
# 45.24% complete
# 45.51% complete
# 45.78% complete
# 46.05% complete
# 46.32% complete
# 46.59% complete
# 46.86% complete
# 47.13% complete
# 47.40% complete
# 47.67% complete
# 47.94% complete
# 48.20% complete
# 48.47% complete
# 48.74% complete
# 49.01% complete
# 49.28% complete
# 49.55% complete
# 49.82% complete
# 50.09% complete
# 50.36% complete
# 50.63% complete
# 50.90% complete
# 51.17% complete
# 51.44% complete
# 51.71% complete
# 51.97% complete
# 52.24% complete
# 52.51% complete
# 52.78% complete
# 53.05% complete
# 53.32% complete
# 53.59% complete
# 53.86% complete
# 54.13% complete
# 54.40% complete
# 54.67% complete
# 54.94% complete
# 55.21% complete
# 55.48% complete
# 55.75% complete
# 56.01% complete
# 56.28% complete
# 56.55% complete
# 56.82% complete
# 57.09% complete
# 57.36% complete
# 57.63% complete
# 57.90% complete
# 58.17% complete
# 58.44% complete
# 58.71% complete
# 58.98% complete
# 59.25% complete
# 59.52% complete
# 59.78% complete
# 60.05% complete
# 60.32% complete
# 60.59% complete
# 60.86% complete
# 61.13% complete
# 61.40% complete
# 61.67% complete
# 61.94% complete
# 62.21% complete
# 62.48% complete
# 62.75% complete
# 63.02% complete
# 63.29% complete
# 63.55% complete
# 63.82% complete
# 64.09% complete
# 64.36% complete
# 64.63% complete
# 64.90% complete
# 65.17% complete
# 65.44% complete
# 65.71% complete
# 65.98% complete
# 66.25% complete
# 66.52% complete
# 66.79% complete
# 67.06% complete
# 67.32% complete
# 67.59% complete
# 67.86% complete
# 68.13% complete
# 68.40% complete
# 68.67% complete
# 68.94% complete
# 69.21% complete
# 69.48% complete
# 69.75% complete
# 70.02% complete
# 70.29% complete
# 70.56% complete
# 70.83% complete
# 71.10% complete
# 71.36% complete
# 71.63% complete
# 71.90% complete
# 72.17% complete
# 72.44% complete
# 72.71% complete
# 72.98% complete
# 73.25% complete
# 73.52% complete
# 73.79% complete
# 74.06% complete
# 74.33% complete
# 74.60% complete
# 74.87% complete
# 75.13% complete
# 75.40% complete
# 75.67% complete
# 75.94% complete
# 76.21% complete
# 76.48% complete
# 76.75% complete
# 77.02% complete
# 77.29% complete
# 77.56% complete
# 77.83% complete
# 78.10% complete
# 78.37% complete
# 78.64% complete
# 78.90% complete
# 79.17% complete
# 79.44% complete
# 79.71% complete
# 79.98% complete
# 80.25% complete
# 80.52% complete
# 80.79% complete
# 81.06% complete
# 81.33% complete
# 81.60% complete
# 81.87% complete
# 82.14% complete
# 82.41% complete
# 82.68% complete
# 82.94% complete
# 83.21% complete
# 83.48% complete
# 83.75% complete
# 84.02% complete
# 84.29% complete
# 84.56% complete
# 84.83% complete
# 85.10% complete
# 85.37% complete
# 85.64% complete
# 85.91% complete
# 86.18% complete
# 86.45% complete
# 86.71% complete
# 86.98% complete
# 87.25% complete
# 87.52% complete
# 87.79% complete
# 88.06% complete
# 88.33% complete
# 88.60% complete
# 88.87% complete
# 89.14% complete
# 89.41% complete
# 89.68% complete
# 89.95% complete
# 90.22% complete
# 90.48% complete
# 90.75% complete
# 91.02% complete
# 91.29% complete
# 91.56% complete
# 91.83% complete
# 92.10% complete
# 92.37% complete
# 92.64% complete
# 92.91% complete
# 93.18% complete
# 93.45% complete
# 93.72% complete
# 93.99% complete
# 94.25% complete
# 94.52% complete
# 94.79% complete
# 95.06% complete
# 95.33% complete
# 95.60% complete
# 95.87% complete
# 96.14% complete
# 96.41% complete
# 96.68% complete
# 96.95% complete
# 97.22% complete
# 97.49% complete
# 97.76% complete
# 98.03% complete
# 98.29% complete
# 98.56% complete
# 98.83% complete
# 99.10% complete
# 99.37% complete
# 99.64% complete
# 99.91% complete
# Issue found on line จัดการกิจกรรมทั้งหมด: จัดการกิจกรรมทั้งหมด
# [('against', 'ขัดต่อ'), ('alignemnt', 'การจัดตำแหน่ง'), ('allocate', 'จัดสรร'), ('applicant', 'ผู้สมัคร'), ('application form', 'แบบฟอร์มใบสมัคร'), ('arrogance', 'ความเย่อหยิ่ง'), ('as of', 'อย่าง'), ('as to', 'ว่า'), ('atonement', 'การชดใช้'), ('benefit', 'ผลประโยชน์'), ('brace', 'รั้ง'), ('capital', 'เมืองหลวง'), ('clearance', 'การกวาดล้าง'), ('competitive', 'การแข่งขัน'), ('confirm', 'ยืนยัน'), ('confirm rights', 'ยืนยันสิทธิ์'), ('conflict', 'ขัดแย้ง'), ('congruity', 'ความสมานฉันท์'), ('crow', 'อีกา'), ('cultivate', 'ฝึกฝน'), ('decisive', 'เด็ดขาด'), ('demand', 'ความต้องการ'), ('dignity', 'ศักดิ์ศรี'), ('diligent', 'ขยัน'), ('dispute', 'ข้อพิพาท'), ('divert', 'เบี่ยงเบนความสนใจ'), ('domestic', 'ภายในประเทศ'), ('eligible', 'มีสิทธิ์'), ('ensure', 'ทำให้มั่นใจ'), ('envelope', 'ซองจดหมาย'), ('evade', 'หลีกเลี่ยง'), ('fare', 'ค่าอาหาร'), ('fee', 'ค่าธรรมเนียม'), ('fine', 'ดี'), ('grave', 'หลุมฝังศพ'), ('idiot', 'งี่เง่า'), ('imitate', 'เลียนแบบ'), ('imprison', 'ถูกกักขัง'), ('individual', 'รายบุคคล'), ('interference', 'การรบกวน'), ('liberty', 'เสรีภาพ'), ('literal', 'ตามตัวอักษร'), ('management', 'การจัดการ'), ('manifest', 'ประจักษ์'), ('mass', 'มวล'), ('merciful', 'มีเมตตา'), ('merit', 'บุญ'), ('moderation', 'การกลั่นกรอง'), ('neglect', 'ละเลย'), ('nonetheless', 'อย่างไรก็ตาม'), ('painting', 'จิตรกรรม'), ('perceive', 'รับรู้'), ('perish', 'ล่มจม'), ('pledge', 'จำนำ'), ('popularity', 'ความนิยม'), ('population', 'ประชากร'), ('possess', 'มี'), ('post office', 'ที่ทำการไปรษณีย์'), ('practically', 'อย่างปฏิบัติ'), ('predicament', 'สถานการณ์'), ('promise', 'สัญญา'), ('provide', 'จัดเตรียม'), ('rapidly', 'อย่างรวดเร็ว'), ('refer to', 'อ้างถึง'), ('reincarnation', 'การกลับชาติมาเกิด'), ('repair', 'ซ่อมแซม'), ('residue', 'สารตกค้าง'), ('resolution', 'ปณิธาน'), ('restrain', 'ยับยั้ง'), ('scholastic', 'เกี่ยวกับนักวิชาการ'), ('screw', 'สกรู'), ('serve', 'ให้บริการ'), ('severe', 'รุนแรง'), ('so as', 'ดังนั้น'), ('spread', 'การแพร่กระจาย'), ('stab', 'แทง'), ('stroke', 'จังหวะ'), ('succession', 'การสืบทอด'), ('suspicious', 'สงสัย'), ('towel', 'ผ้าขนหนู'), ('usage', 'การใช้งาน'), ('vaporize', 'ทำให้เป็นไอ'), ('versatile', 'อเนกประสงค์'), ('yield', 'ผลผลิต')]
# Vocabulary written to vocab.txt
